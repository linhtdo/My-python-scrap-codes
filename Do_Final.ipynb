# %% [markdown]
# # Analytics Programming – Python
# # MIS/MIT 5970
# ## Instructor: Dr. Kazim Topuz
# ## Final
#
#
# Name the file “YourLastName_Final” with appropriate file extension<br />
# Submit .ipynb (this) file to the canvas<br />
# If the question is not clear for you:<br />
#     - Use your judgement
#     - State your assumptions (what do you understand)
#     - Solve the problem
# Good luck!

# %% [markdown]
# # Part 1 (30 points)
# ## Basic Operations
# ### Q1: Write a Python program to print the following string in a specific format (see the output).
#   Output:
#
#     Boomer Sooner, Boomer Sooner
#         Boomer Sooner, OK U!
#
#     Oklahoma, Oklahoma
#         Oklahoma, OK U!

# %%
# Answer here
print("Boomer Sooner, Boomer Sooner \n     Boomer Sooner, OK U! \n\nOklahoma, Oklahoma \n     Oklahoma, OK U! ")
# Out:
# Boomer Sooner, Boomer Sooner
#      Boomer Sooner, OK U!
#
# Oklahoma, Oklahoma
#      Oklahoma, OK U!

# %% [markdown]
# ### Q2: Write a Python program to let user enter three integers then sort these integers without using conditional statements and loops.
#     Hint: You can use min, max...
#     Sample output:
#         Enter the first number: 6
#         Enter the second number: 1
#         Enter the third number: 3
#         Numbers in sorted order:  1 3 6

# %%
#### Answer here
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))
out = [num1,num2,num3]
out.sort()
print("Numbers in sorted order: %s" %out)
# Out:
# Enter the first number: 98
# Enter the second number: 57
# Enter the third number: 32
# Numbers in sorted order: [32, 57, 98]

# %% [markdown]
# ### Q3: List, Dictionary and Tuples
# #### A: Lists:<br>
# - Create list1 = ["Norman", 2, "Tulsa", 6, ["NJ", "OK", "PA"], "Edmond", "Broked Arrow", "OKC"]
# - Replace "Broked Arrow" with "Broken Arrow" in list1
# - Remove all but OK cities in list 1 and save the new list as 'cities'
# - Create pop = [120,403,90,106,600]

# %%
# Answer here
list1 = ["Norman", 2, "Tulsa", 6, ["NJ", "OK", "PA"], "Edmond", "Broked Arrow", "OKC"]
print(list1)
# Out:
# ['Norman', 2, 'Tulsa', 6, ['NJ', 'OK', 'PA'], 'Edmond', 'Broked Arrow', 'OKC']

# %%
list1[6] = "Broken Arrow"
print(list1)
# Out:
# ['Norman', 2, 'Tulsa', 6, ['NJ', 'OK', 'PA'], 'Edmond', 'Broken Arrow', 'OKC']

# %%
cities = list1
del(cities[4])
cities.remove(2)
cities.remove(6)

print(cities)
# Out:
# ['Norman', 'Tulsa', 'Edmond', 'Broken Arrow', 'OKC']

# %%
pop = [120,403,90,106,600]
print(pop)
# Out:
# [120, 403, 90, 106, 600]

# %% [markdown]
# #### B: Dictionary:
# - Create a dictionary called 'OKCities' using 'cities' and 'pop' lists (key= cities)
# - Add 'Moore' and ' Lawton to the dictionary with pop values 60, and 96
# - Change the value for 'OKC' to 631
# - Print the dictionary

# %%
# Answer here
OKCities = dict(zip(cities,pop))
OKCities
# Out:
# {'Broken Arrow': 106, 'Edmond': 90, 'Norman': 120, 'OKC': 600, 'Tulsa': 403}

# %%
OKCities['Moore'] = 60
OKCities['Lawton'] = 96
OKCities['OKC'] = 631
print(OKCities)
# Out:
# {'Norman': 120, 'Tulsa': 403, 'Edmond': 90, 'Broken Arrow': 106, 'OKC': 631, 'Moore': 60, 'Lawton': 96}

# %% [markdown]
# # Part 2 (35 points)
# ## Conditionals, Loops, and Functions
# ### Q1: Use conditionals to find the median of three values, let user enter three values (see the output).
#   Output:
#
#     Enter the first number: 15
#     Enter the second number: 105
#     Enter the third number: 50
#     The median is 50.0

# %%
# Answer here
import numpy as np
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))
out = [num1,num2,num3]
med = np.median(out)

print("The median is %d" %med)
# Out:
# Enter the first number: 15
# Enter the second number: 105
# Enter the third number: 50
# The median is 50

# %% [markdown]
# ### Q2: Write a Python function to sum all the numbers in a list.
#  - Sample list= [23,45,1,-4,5]

# %%
# Answer here
sample= [23,45,1,-4,5]
sum_list = np.sum(sample)
print(sum_list)
# Out:
# 70

# %% [markdown]
# ### Q3: Numpy Operations
# - Create a 6x6 array with random values between 0 and 100
# - find the minimum and maximum values
# - find the horizontal sum of the rows
# - convert values to percentages (divide each value to 100)

# %%
# Answer here
my_array = np.random.randint(100,size=(6,6))
my_array
# Out:
# array([[15, 36,  9, 22, 66, 47],
#        [71, 99, 33, 79, 84, 13],
#        [19, 61, 88, 64, 35, 74],
#        [38, 75, 40, 98, 56, 79],
#        [11, 16, 58, 34, 67, 69],
#        [82, 73, 55, 61, 59, 64]])

# %%
minimum = np.min(my_array)
print(minimum)

maximum = np.max(my_array)
print(maximum)
# Out:
# 9
# 99

# %%
horizontal_sum = np.sum(my_array, axis=1)
print(horizontal_sum)
# Out:
# [195 379 341 386 255 394]

# %%
percentage = my_array/100
percentage
# Out:
# array([[ 0.15,  0.36,  0.09,  0.22,  0.66,  0.47],
#        [ 0.71,  0.99,  0.33,  0.79,  0.84,  0.13],
#        [ 0.19,  0.61,  0.88,  0.64,  0.35,  0.74],
#        [ 0.38,  0.75,  0.4 ,  0.98,  0.56,  0.79],
#        [ 0.11,  0.16,  0.58,  0.34,  0.67,  0.69],
#        [ 0.82,  0.73,  0.55,  0.61,  0.59,  0.64]])

# %% [markdown]
# # Part 3 (40 points)
# ## Case Study
#
# The Olympic medal data for the following exercises comes from The Guardian. It comprises records of all events held at the Olympic games between 1896 and 2012. More than 35,000 medals have been awarded at the Olympics since 1896. The first two Olympiads awarded silver medals and an olive wreath for the winner, and the IOC retrospectively awarded gold, silver, and bronze to athletes based on their rankings. This dataset includes a row for every Olympic athlete that has won a medal since the first games.
#
# - Acknowledgements
#
#     - Data was provided by the IOC Research and Reference Service and published by The Guardian's Datablog.

# %% [markdown]
# ## A. Look and concat your data
#
# Lets chech the olympic medals around the globe.
#
# The DataFrame `summer` and `winter` have been saved as `csv`. Your first task in this exercise is to import numpy, pandas and matplotlib, save the dataframes as `summer` and `winter`, and concatenate them into one. See the specific instructions.
#
#
# ### Instructions
# - Import `numpy`, `matplotlib.pyplot` and `pandas`.
# - Import and save the data from `summer.csv` as `summer`.
# - Import and save the data from `winter.csv` as `winter`.
# - Print the head and tail of `summer` and `winter`.
# - Concatenate two datasets (summer and winter) into one DataFrame called `olympics`.
# - Print the shape and column names of the concatenated DataFrame.

# %%
# Answer here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

summer = pd.read_csv('summer.csv')
winter = pd.read_csv('winter.csv')

print(summer.head(2))
print(summer.tail(2))
print(winter.head(2))
print(winter.tail(2))
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver
#        Year    City      Sport           Discipline            Athlete  \
# 31163  2012  London  Wrestling  Wrestling Freestyle  ALEKSANYAN, Artur
# 31164  2012  London  Wrestling  Wrestling Freestyle     LIDBERG, Jimmy
#
#       Country Gender     Event   Medal
# 31163     ARM    Men  Wg 96 KG  Bronze
# 31164     SWE    Men  Wg 96 KG  Bronze
#    Year      City     Sport Discipline         Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon     BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon  MANDRILLON, C.     FRA    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# ...

# %%
olympics = pd.concat([summer, winter])
print(olympics.shape)
print(olympics.columns)
# Out:
# (36935, 9)
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %%
# Out:
#    Year    City     Sport Discipline           Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver
#       Year   City   Sport Discipline           Athlete Country Gender  \
# 5768  2014  Sochi  Skiing  Snowboard      SAMKOVA, Eva     CZE  Women
# 5769  2014  Sochi  Skiing  Snowboard  TRESPEUCH, Chloe     FRA  Women
#
#                 Event   Medal
# 5768  Snowboard Cross    Gold
# 5769  Snowboard Cross  Bronze
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# ## B. Missing value analysis
#
# Now it is time to check unclean or missing data.
# ### Instructions
# - Use describe (including categorical columns) and note the Athlete that won the most medals with the frequency (number of medals he got) as a comment.
# - Identify in which column the missing values are present.
# - Replace the missing values in `Country` with `NoMansLand` and save the data.
# - Print the records of `NoMansLand` that got the `Gold` Medal
# - Check that if the `Year` column is of type np.int64
# - Print the shape and the head of the DataFrame

# %%
olympics.describe(include='all')
# PHELPS, Michael was the athlete that won the most medal (frequency = 22)
# Out:
#                 Year    City     Sport Discipline          Athlete Country  \
# count   36935.000000   36935     36935      36935            36935   36931
# unique           NaN      41        48         80            26495     148
# top              NaN  London  Aquatics  Athletics  PHELPS, Michael     USA
# freq             NaN    3567      4170       3638               22    5238
# mean     1972.961635     NaN       NaN        NaN              NaN     NaN
# std        32.447833     NaN       NaN        NaN              NaN     NaN
# min      1896.000000     NaN       NaN        NaN              NaN     NaN
# 25%      1952.000000     NaN       NaN        NaN              NaN     NaN
# 50%      1980.000000     NaN       NaN        NaN              NaN     NaN
# 75%      2000.000000     NaN       NaN        NaN              NaN     NaN
# max      2014.000000     NaN       NaN        NaN              NaN     NaN
#
#        Gender       Event  Medal
# count   36935       36935  36935
# ...

# %%
olympics.dropna(axis=1, inplace= False)
# Country is the only column that has NA values
# Out:
#       Year    City      Sport Discipline                      Athlete Gender  \
# 0     1896  Athens   Aquatics   Swimming                HAJOS, Alfred    Men
# 1     1896  Athens   Aquatics   Swimming             HERSCHMANN, Otto    Men
# 2     1896  Athens   Aquatics   Swimming            DRIVAS, Dimitrios    Men
# 3     1896  Athens   Aquatics   Swimming           MALOKINIS, Ioannis    Men
# 4     1896  Athens   Aquatics   Swimming           CHASAPIS, Spiridon    Men
# 5     1896  Athens   Aquatics   Swimming        CHOROPHAS, Efstathios    Men
# 6     1896  Athens   Aquatics   Swimming                HAJOS, Alfred    Men
# 7     1896  Athens   Aquatics   Swimming             ANDREOU, Joannis    Men
# 8     1896  Athens   Aquatics   Swimming        CHOROPHAS, Efstathios    Men
# 9     1896  Athens   Aquatics   Swimming                NEUMANN, Paul    Men
# 10    1896  Athens   Aquatics   Swimming            PEPANOS, Antonios    Men
# ...

# %%
olympics['Country'].fillna(value = 'NoMansLand', inplace = True)
olympics[(olympics['Country'] == 'NoMansLand') & (olympics['Medal']=='Gold')]
# Out:
#        Year    City          Sport     Discipline  Athlete     Country Gender  \
# 29603  2012  London      Athletics      Athletics  Pending  NoMansLand  Women
# 31072  2012  London  Weightlifting  Weightlifting  Pending  NoMansLand  Women
#
#        Event Medal
# 29603  1500M  Gold
# 31072   63KG  Gold

# %%
print(olympics['Year'].dtype)
# Out:
# int64

# %%
olympics.shape
olympics.head(5)
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
# Out:
#                 Year    City     Sport Discipline          Athlete Country  \
# count   36935.000000   36935     36935      36935            36935   36935
# unique           NaN      41        48         80            26495     149
# top              NaN  London  Aquatics  Athletics  PHELPS, Michael     USA
# freq             NaN    3567      4170       3638               22    5238
# mean     1972.961635     NaN       NaN        NaN              NaN     NaN
# std        32.447833     NaN       NaN        NaN              NaN     NaN
# min      1896.000000     NaN       NaN        NaN              NaN     NaN
# 25%      1952.000000     NaN       NaN        NaN              NaN     NaN
# 50%      1980.000000     NaN       NaN        NaN              NaN     NaN
# 75%      2000.000000     NaN       NaN        NaN              NaN     NaN
# max      2014.000000     NaN       NaN        NaN              NaN     NaN
#
#        Gender       Event  Medal
# count   36935       36935  36935
# ...

# %% [markdown]
# ## C. Further analysis
#
# It's time to do more analysis.
#
# ### Instructions
# - First we will create a dataFrame called `usamedals` with data only for the USA.
# - Group the `usamedals` data by year and medal and save the result as `usa_by_year` with Year and Medal to see how many Gold, Silver, or Bronze medal was given by year.
# - Then, we will see the medals in Cold War era. As you know the Cold War between the United States of America (USA) & the Union of Soviet Socialist Republics (URS) took place between 1952 and 1988. Create a dataframe called `cold_medals` by extracting all rows from `olympics` for which the `Year` is >= 1952 and <= 1988 and the `Country` is USA or URS.
# - Group by the `cold_medals` dataframe and print which Country won the most medals over the Cold War period.

# %%
usamedals = olympics[olympics['Country']=='USA']
#usamedals

# %%
#Group the usamedals data by year and medal and save the result as usa_by_year with Year and Medal 
#to see how many Gold, Silver, or Bronze medal was given by year.

usa_by_year = usamedals.groupby(['Year','Medal'])
print(usa_by_year.describe())
# Out:
#             Athlete                                        City         \
#               count unique                       top freq count unique
# Year Medal
# 1896 Bronze       2      2           CONNOLLY, James    1     2      1
#      Gold        11      8           GARRETT, Robert    2    11      1
#      Silver       7      6           GARRETT, Robert    2     7      1
# 1900 Bronze      14     12           GARRETT, Robert    2    14      1
#      Gold        27     20         KRAENZLEIN, Alvin    4    27      1
#      Silver      14     11            BAXTER, Irving    3    14      1
# 1904 Bronze     111     96             MERZ, William    4   111      1
#      Gold       146    118              HEIDA, Anton    5   146      1
#      Silver     137    125            COOKE, Emma C.    3   137      1
# 1908 Bronze      15     15      EISELE, John Lincoln    1    15      1
#      Gold        34     30          SHEPPARD, Melvin    3    34      1
# ...

# %%
#Create a dataframe called cold_medals by extracting all rows from olympics for which the Year is >= 1952 and <= 1988 
#and the Country is USA or URS
cold_medals = olympics[(olympics['Year'] >= 1952) & (olympics['Year'] <= 1988) & (olympics['Country'] == 'USA') | (olympics['Country']=='URS')]
cold_medals
# Out:
#       Year      City      Sport            Discipline  \
# 8019  1952  Helsinki   Aquatics                Diving
# 8021  1952  Helsinki   Aquatics                Diving
# 8022  1952  Helsinki   Aquatics                Diving
# 8023  1952  Helsinki   Aquatics                Diving
# 8024  1952  Helsinki   Aquatics                Diving
# 8025  1952  Helsinki   Aquatics                Diving
# 8026  1952  Helsinki   Aquatics                Diving
# 8027  1952  Helsinki   Aquatics                Diving
# 8028  1952  Helsinki   Aquatics                Diving
# 8030  1952  Helsinki   Aquatics              Swimming
# 8031  1952  Helsinki   Aquatics              Swimming
# 8037  1952  Helsinki   Aquatics              Swimming
# 8043  1952  Helsinki   Aquatics              Swimming
# 8047  1952  Helsinki   Aquatics              Swimming
# 8053  1952  Helsinki   Aquatics              Swimming
# 8054  1952  Helsinki   Aquatics              Swimming
# ...

# %%
#Group by the cold_medals dataframe and print which Country won the most medals over the Cold War period
cold_medals.groupby(['Country','Medal']).count()
# Out:
#                 Year  City  Sport  Discipline  Athlete  Gender  Event
# Country Medal
# URS     Bronze   677   677    677         677      677     677    677
#         Gold    1088  1088   1088        1088     1088    1088   1088
#         Silver   724   724    724         724      724     724    724
# USA     Bronze   351   351    351         351      351     351    351
#         Gold     793   793    793         793      793     793    793
#         Silver   531   531    531         531      531     531    531

# %%
# Answer here
# Out:
#                 Year  City  Sport  Discipline  Athlete  Gender  Event
# Country Medal
# URS     Bronze   677   677    677         677      677     677    677
#         Gold    1088  1088   1088        1088     1088    1088   1088
#         Silver   724   724    724         724      724     724    724
# USA     Bronze   351   351    351         351      351     351    351
#         Gold     793   793    793         793      793     793    793
#         Silver   531   531    531         531      531     531    531

# %% [markdown]
# ## D. Lets plot
#
# Now that you have a clean and tidy dataset, you can do a bit of visualization and aggregation.
#
# - In this exercise, you'll create two subplots (1 row, 2 columns);
#     - Begin by creating a histogram of the `Year` column using `olympics` data (dont forget to put labels and title) and show the plot inline.
#
#     - Your Second plot will visualize the medal counts by `Year` for the `USA`. This time, you will use a line plot to see the breakdown better (dont forget to put labels and title) and show the plot inline. The line plot should include `color` and `marker` of your choice with `linewidth =2`. (Hint: You can use the `groupby()` method on `usamedals` with `Year` and `Medal`, then chain with `count`.
#
# - Finally, save both DataFrames (`olympics` and `usa_by_year`) to the file as `csv`.

# %%
olympics['Year'].plot(kind='hist', title = 'Histogram',label = 'Year')
plt.show()

# %%
medal_by_year = usamedals.groupby(['Year'])['Medal'].count()
medal_by_year.head(5)
# Out:
# Year
# 1896     20
# 1900     55
# 1904    394
# 1908     63
# 1912    101
# Name: Medal, dtype: int64

# %%
medal_by_year.plot(title='USA Medals',color ='green', linewidth =2,linestyle = '-',marker = '*')
plt.show()

# %%
#save both DataFrames (olympics and usa_by_year) to the file as csv.
olympics.to_csv('olympics.csv')
#usa_by_year.to_csv('usa_by_year.csv')

# %%
# Answer here
# Out:
# Year
# 1896     20
# 1900     55
# 1904    394
# 1908     63
# 1912    101
# Name: Medal, dtype: int64

# %% [markdown]
# # ! GOOD LUCK  !
